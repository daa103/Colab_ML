# %% [markdown]
# <a href="https://colab.research.google.com/github/daa103/DAA_ESAA/blob/main/datavisualizaiton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 두잇판다스 데이터시각화 81p~119p
#
# ##**04-1 데이터 시각화가 필요한 이유**
# > ### 앤스콤 4분할 그래프
#  * 4개의 데이터 그룹
#  * 평균,분산, 같은 수칫값과 상관관계, 회귀선이 같다.
#  * 결과를 통해 데이터그룹은 모두 같을것이라고 착각할 수 있지만 시각화를통해 차별점을 확인할 수 있다.
#  * 앤스콤 데이터집합은 seaborn 라이브러리에 포함되어있다.

# %% [markdown]
# > #### 1. 앤스콤 데이터집합 불러오기

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
anscombe=sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# > #### 2. matplotlib 라이브러리로 그래프그리기
# > 그래프를 그리기위해 matplotlib 라이브러리 사용

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# > 3. anscombe 데이터프레임의 dataset열에서 데이터값이 1인것만 추출

# %%
dataset_1=anscombe[anscombe['dataset']=='I']

# %% [markdown]
# > 4. 선그래프는 plot method에 x,y축 데이터를 전달한다

# %%
print(dataset_1)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset_1['x'],dataset_1['y'])
plt.show()

# %% [markdown]
# > 5. plot 메서드는 선그래프, 점그래프는 o를 세번째 인자로 전달하면된다

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')
plt.show()

# %% [markdown]
# > ### 앤스콤 데이터집합 모두 이용하여 그래프 만들기
# >>  #### matplotlib라이브러리로 그래프 그리기
# 1. 전체그래프가 위치할 기본 틀 만들기
# 2. 그래프를 그려 넣을 그래프 격자 만들기
# 3. 격자그래프 하나씩 추가( 왼쪽에서 오른쪽방향)
# 4. 격자의 첫행이 꽉차면 두번째 행에 그래프 넣기기

# %% [markdown]
# >> 1. 앤스콤 데이터프레임의 dataset열의 값이 1,2,3,4인 것을 불린 추출하여 dataset_1,2,3,4 저장

# %%
dataset_2=anscombe[anscombe['dataset']=='II']
dataset_3=anscombe[anscombe['dataset']=="III"]
dataset_4=anscombe[anscombe['dataset']=="IV"]

# %% [markdown]
# >> 2. 그래프 격자 위치할 기본 틀 만들기

# %%
fig=plt.figure()
fig.show()

# %% [markdown]
# >> 3. add_subplot 메서드로 그래프 격자를 그리고 기본틀에 격자를 추가하는 식으로 메서드사용. add_subplot의 첫번째 인자에는 기본틀의 행의크기, 두번째인자는 그래프 기본 틀의 열의 크기 지정정

# %%
fig=plt.figure()
axes1=fig.add_subplot(2,2,1)
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)

# %% [markdown]
# >> 4. plot 메서드에 데이터를 전달하여 그린다. 점으로 그래프로 표현하고 fig를 반드시 입력해야한다.

# %%
axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')
fig

# %% [markdown]
# >> 5. 그래프를 쉽게 구분하는 제목을 추가한다. set_title메서드로 제목으로 추가된다.

# %%
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')
fig

# %% [markdown]
# >> 6.기본틀(fig)에도 suptitle메서드를 통해 기본틀에 제목을 추가한다.

# %%
fig.suptitle('Anscombe Data')
fig

# %% [markdown]
# >> 7.이름과 그래프가 겹쳐보이지 않기위해 tight_layout

# %%
fig.tight_layout()
fig

# %% [markdown]
# ##**04-2 matplotlib 라이브러리 자유자재로 사용하기**
#
# > ### 기초그래프 그리기-히스토그램, 산점도 그래프, 박스 그래프
# >> 1. tips 데이터집합은 변수 tips에 저장

# %%
tips=sns.load_dataset('tips')
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# >> 2. 히스토그램은 데이터프레임의 열 데이터 분포와 빈도를 살피는 용도의 그래프프, total_bill, tip등의 열을 변수라고 부른다. 변수를 하나만 사용하는것은 '일변량 그래프'이다.
# >> 3. 기본틀(fig)마련하고 격자(axes1)를 구성

# %%
fig=plt.figure()
axes1=fig.add_subplot(1,1,1)

# %% [markdown]
# >> 4. hist메서드에 total_bill열을 전달하면 히스토그램이 만들어진다. x축의 간격은 bins인잣값으로 조정.

# %%
axes1.hist(tips['total_bill'],bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
fig

# %% [markdown]
# >> 5. 산점도는 변수 2개를 사용해서 만든 것은 '이변량 그래프'이다.
# >> 6. 기본틀과 그래프 격자를 만들고 scatter메서드에 total_bill, tips 열을 전달하면  total_bill과 tips에 대한 산점도 그래프를 그린다.

# %%
scatter_plot=plt.figure()
axes1=scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('Scatterplot of Totla Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# >> 7. 박스그래프는 이산형변수와 연속형 변수를 함께사용한다.이산형변수는 명확하게 구분되는 값이고 연속형 변수는 셀수없는 범위를 의미한다.
# >> 8. boxplot메서드를 이용해 박스 그래프를 그린다. tips 데이터프레임에서 labels인잣값으로 성별을 구분하여 리스트를 작성하다.

# %%
boxplot=plt.figure()
axes1=boxplot.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Female']['tip'],
               tips[tips['sex']=='Male']['tip']],
              labels=['Female','Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# > ### 다변량 그래프 그리기
# * 3개이상 변수를 사용한 그래프는 다변량 그래프
# > #### 다변량 데이터로 다변량 그래프 그리기-산점도 그래프
# >> 1. scatter_plot에 성별을 새 변수로 추가할때, 문자열은 산점도 그래프의  색상을 지정하는 값으로 사용할 수 없기 때문에 치환하는 함수를 만들어야한다.

# %%
def recode_sex(sex):
  if sex=='Female':
    return 0
  else:
    return 1

# %% [markdown]
# >> 2. recode_sex가 반환한 값을 데이터프레임에 추가하면 데이터프레임에 새로운 열을 추가한다.

# %%
tips['sex_color']=tips['sex'].apply(recode_sex)

# %% [markdown]
# >> 3. 인원수도 치환값을 구하여 산점도에 추가한다.

# %%
scatter_plot=plt.figure()
axes1=scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip colored by sex and sized by size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ##**04-3 seaborn 라이브러리 자유자재 이용**
# > ### 단변량 그래프 그리기-히스토그램
# >> 1. seaborn 라이브러리를 간단하게 줄인다.

# %%
import seaborn as sns
tips=sns.load_dataset("tips")

# %% [markdown]
# >> 2. subplots, distplot을 이용하여 히스토그램을 그리고, total_bill열 데이터를 전달하면 히스토그램을 그릴 수 있다.

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <ipython-input-25-ce4ae7b162d4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %% [markdown]
# >> 3. distplot메서드를 사용하여 히스토그램과 밀집도 그래프를 같이 그릴 수 있다. 제외하려면 kde인잣값을 False로 설정한다.

# %%
ax=plt.subplots()
ax= sns.distplot(tips['total_bill'],kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <ipython-input-26-8a52773ff51c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tips['total_bill'],kde=False)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# >> 4. 밀집도 그래프만 나타내려면 hist 인자를 False로 지정한다.

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <ipython-input-27-83c6e32edcfc>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(tips['total_bill'],hist=False)
# Text(0, 0.5, 'Unit Probability')

# %% [markdown]
# >>5. 그래프를 한번에 출력하는 것은 히스토그램과 밀집도를 그리는 distplot메서드에 rug인자를 추가한다.

# %%
ax= plt.subplots()
ax= sns.distplot(tips['total_bill'],rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
ax
# Out:
# <ipython-input-28-7b92c0c14ffb>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tips['total_bill'],rug=True)
# <Axes: title={'center': 'Total Bill Histogram with Density and Rug Plot'}, xlabel='Total Bill', ylabel='Density'>

# %% [markdown]
# >> 6. count 그래프는 이산값을 나타낸 그래프이고 countplot 메서드에 tips 데이터프레임의 day 열 데이터를 넣어 count그래프는 다음과 같다.

# %%
ax=plt.subplots()
ax=sns.countplot(x="day", data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# >> 1. seaborn 라이브러리로 산점도 그래프 그리기
# regplot메서드를 사용하여 산점도그래프와 회귀귀선을 함께 그린다(회귀선을 제거하려면 fit_reg인자를 False로 지정하면 된다.)

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Totla Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips,fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# >>3. jointplot은 산점도와 히스토그램을 한번에 그려준다.

# %%
joint=sns.jointplot(x='total_bill',y='tip',data=tips)
joint.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip',fontsize=10,y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# >> 3.데이터를 구분하기 쉽게 육각그래프를 사용하여 데이터를 구분한다. kind인잣값을 hex로 지정한다.

# %%
hexbin=sns.jointplot(x='total_bill',y='tip',data=tips,kind="hex")
hexbin.set_axis_labels(xlabel="Total Bill",ylabel="Tip")
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip',fontsize=10,y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# >>4. 이차원 밀집도는 kdeplot으로 그릴 수 있다. shade=True는 음영효과과

# %%
ax=plt.subplots()
ax=sns.kdeplot(x=tips['total_bill'],
               y=tips['tip'],
               shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <ipython-input-34-ecf4b6ee742a>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax=sns.kdeplot(x=tips['total_bill'],
# Text(0, 0.5, 'Tip')

# %% [markdown]
# >>5. 바그래프 그리기

# %%
ax=plt.subplots()
ax=sns.barplot(x='time',y='total_bill',data=tips)
ax.set_title('bar plot of average total bill for time of day')
ax.set_xlabel('time of day')
ax.set_ylabel('average total bill')
# Out:
# Text(0, 0.5, 'average total bill')

# %% [markdown]
# >> 6. 박스그래프 그리기

# %%
ax=plt.subplots()
ax=sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('boxplot of total bill by time of day')
ax.set_xlabel('time of day')
ax.set_ylabel('total billl')
# Out:
# Text(0, 0.5, 'total billl')

# %% [markdown]
# >> 7.violinplot 매서드

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill', data=tips)
ax.set_title('violin plot of total bil by time of day')
ax.set_xlabel('time of day')
ax.set_ylabel('total bill')
# Out:
# Text(0, 0.5, 'total bill')

# %% [markdown]
# >>8.관계 그래프-종합그래프

# %%
fig=sns.pairplot(tips)

# %% [markdown]
# >> 9.관계그래프는 중복정보가 포함되므로 원하는 그래프로 교체시킨다. map_upper은 대각선기준 위, map_lower은 대각선기준 아래를 그린다.

# %%
#regplot은 회귀선그래프, kdeplot은 이차원 밀집도
pair_grid=sns.PairGrid(tips)
pair_grid=pair_grid.map_upper(sns.regplot)
pair_grid=pair_grid.map_lower(sns.kdeplot)
pair_grid=pair_grid.map_diag(sns.displot, rug=True)
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# > ### 다변량그래프그리기
# >> 1.seaborn 라이브러리로 바이올린그래프 그리고 색상추가

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# >>2. 산점도, 관계 그래프 그리기

# %%
scatter=sns.lmplot(y='tip', x='total_bill', hue='sex', data=tips,fit_reg=False)
#lmplot: 회귀선+산점도를 한번에 볼 수 있는 그래프

# %%
fig=sns.pairplot(tips,hue='sex')

# %% [markdown]
# >>3. 산점도 그래프 크기와 모양조절
# scatter_kws에 딕셔너리 형태로 인잣값 전달

# %%
scatter=sns.lmplot(x='total_bill',y='tip', data=tips, fit_reg=False, hue='sex',
                   scatter_kws={'s':tips['size']*10})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-9c2b234946fe> in <module>
# ----> 1 scatter=sns.lmplot(x='total_bill',y='tip', data=tips, fit_reg=False, hue='sex',
#       2                    scatter_kws={'s':tips['size']*10})
#
# /usr/local/lib/python3.9/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     633         scatter_kws=scatter_kws, line_kws=line_kws,
#     634     )
# --> 635     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     636     facets.set_axis_labels(x, y)
#     637
#
# ...

# %% [markdown]
# >>4.산점도그래프의 점을 다른기호로 바꾸려면 markers인잣값에 표현하고자하는 기호를 리스트에 담아 전달.

# %%
scatter = sns.lmplot(x='total_bill' y='tip', data=tips, fit_reg=False, hue='sex',markers=['o', 'x'], scatter_kws={'s':tips['size']*10})
# Out:
#   File "<ipython-input-49-ed03704e532c>", line 1
#     scatter = sns.lmplot(x='total_bill' y='tip', data=tips, fit_reg=False, hue='sex',markers=['o', 'x'], scatter_kws={'s':tips['size']*10})
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# >>5. lmplot으로 4개데이터 그룹에 대한 그래프 한번에 그리기기

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
anscombe_plot=sns.lmplot(x='x',y='y',data=anscombe, fit_reg=False)

# %% [markdown]
# >>6. col:데이터그룹을 구분할 열 지정
# col_warp: 그래프를 그릴 열의 최댓값지정

# %%
anscombe_plot=sns.lmplot(x='x',y='y',data=anscombe,fit_reg=False, col='dataset',col_wrap=2)

# %% [markdown]
# >> ### FaceGrid 클래스로 그룹별 그래프 그리기
# >>1. 구분할 열 이름을 전달하여 객체를 생성하고 facet의 map 메서드에 그래프종류와 x축지정열 이름을 작성한다.

# %%
facet=sns.FacetGrid(tips,col='time')
facet.map(sns.distplot,'total_bill',rug=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# >> 다변량그래프를 그릴땐 tips데이터집합의 day열로 그룹을 구분하여 그래프를 그린다.

# %%
facet=sns.FacetGrid(tips,col='day',hue='sex')
facet=facet.map(plt.scatter,'total_bill','tip')
facet=facet.add_legend()

# %%
facet=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
facet.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# > ## **데이터프레임과 시리즈로 그래프 그리기**
# >> 1. 히스토그램은 hist 메서드를 이용한다다

# %%
ax=plt.subplots()
ax=tips['total_bill'].plot.hist()

# %% [markdown]
# >> 2.투명도조절은 alpha,bins,ax인자를 사용한다.

# %%
fig.ax=plt.subplots()
ax=tips[['total_bill','tip']].plot.hist(alpha=0.8,bins=20,ax=ax)

# %% [markdown]
# >> 3. 밀집도, 산점도, 육각그래프는 각각 kde, scatter, hexbin을 통해 그림

# %%
ax=plt.subplots()
ax=tips['tip'].plot.kde()

# %%
fig,ax=plt.subplots()
ax=tips.plot.scatter(x='total_bill',y='tip',ax=ax)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
fig, ax=plt.subplots()
ax= tips.plot.hexbin(x='total_bill',y='tip',ax=ax)

# %% [markdown]
# >> 육각 그래프의 육각형크기는 gridsize를 통해변경경

# %%
fig,ax=plt.subplots()
ax=tips.plot.hexbin(x='total_bill',y='tip',gridsize=10,ax=ax)

# %%
fig, ax=plt.subplots()
ax=tips.plot.box(ax=ax)

# %% [markdown]
# > ## **seaborn 라이브러리로 그래프 스타일 설정**
# >> 그래프에 스타일 적용하기기

# %%
fig,ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)

# %% [markdown]
# >> whitegrid스타일을 설정한다다

# %%
sns.set_style('whitegrid')
fig,ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)

# %% [markdown]
# for문을 통해 스타일 적용

# %%
fig=plt.figure()
seaborn_styles=['darkgrid','whitegrid','dark','white','ticks']
for idx, style in enumerate(seaborn_styles):
  plot_position=idx + 1
  with sns.axes_style(style):
    ax=fig.add_subplot(2,3,plot_position)
    violin=sns.violinplot(x='time',y='total_bill',data=tips,ax=ax)
violin.set_title(style)
fig.tight_layout()
